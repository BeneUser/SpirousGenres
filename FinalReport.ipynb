# %% [markdown]
# ## REI505M Machine Learning - Final Report
# Due: Sunday 21.11.2025
#
# Project: Music genre classification
#
# Group: Spirou (Benedikt Baumgarten, Erik Schwaar, Inken Hofbauer)

# %% [markdown]
# ### 1 Introduction

# %% [markdown]
# ### 2 Methods

# %% [markdown]
# ##### 2.1 1D-CNN Architecture

# %% [markdown]
# ##### 2.2 Audio Data Augmentation

# %% [markdown]
# #### 2.3 Transfer Learning

# %% [markdown]
# ### 3 Results and Analysis

# %% [markdown]
# ### 4 Summary and Outlook
